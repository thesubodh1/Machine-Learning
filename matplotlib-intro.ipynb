# %% [markdown]
# # This section is dedicated to Matplotlib

# %%
import pandas as  pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# this is a figure
plt.plot();

# %%
# to do exact same thing as above
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4]);

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y);

# %%
# 1st method
fig = plt.figure() # create a figure
ax = fig.add_subplot() # add some axes
plt.show()
# long version of plt.plot()

# %%
# 2nd method
fig = plt.figure() # create a figure
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
# 3rd method (recommended object oriented method)
fig,ax = plt.subplots()
ax.plot(x,y); # lets add some data

# %% [markdown]
# ![](anatomy_of_matplotlib_plot.png)

# %%
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# # Matplot lib example workflow

# %%
# 0. import matplotlib and get it ready for plotting
import matplotlib.pyplot as plt

# 1. prepare Data
x = [1,2,3,4]
y = [11,22,33,44]

# 2. setup plot
fig,ax = plt.subplots(figsize=(10,10)) # width and height (x,y)

# 3. plot.data
ax.plot(x,y)

# 4. CUstomize the plot
ax.set(title="Simple Plot",xlabel="x-axis",ylabel="y-axis")

#5. save & show
fig.savefig("test-plot.png")

# %%
# my personal plot
import matplotlib.pyplot as plt

y = [100,500,200,900,150]
x = [5,10,15,20,25]
fig,ax = plt.subplots(figsize=(20,10))
ax.plot(x,y)
ax.set(title="My personal plot",xlabel="X-axis",ylabel="Y-axis")
fig.savefig("personal-plot.png")

# %% [markdown]
# ## Making figures with numpy arrays
#
# we want
# * line plot
# * scatter plot
# * bar plot
# * histogram
# * subplot

# %%
# create some data
x = np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# plot the data and create a line plot
fig,ax = plt.subplots(figsize=(10,10))
ax.plot(x,x**2);

# %%
# plot the data and create Scatter using same data
fig,ax = plt.subplots()
ax.scatter(x,np.exp(x));

# %%
# Another Scatter plot
fig,ax = plt.subplots()
ax.scatter(x,np.sin(x));

# %%
# make a plot form a dict
nut_butter_prices = {"Almond butter":10,"Peanut Butter":8,"Cashew Butter":12}
fig,ax = plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax.set(title="Nut Butter Price Store",ylabel="Price ($)");

# %%
# horizantal bar graph
fig,ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values()));

# %%
# Histogram
# make some data
x = np.random.randn(1000)
fig,ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# # Two options for multiple plots(subplots)

# %%
# Subplot option 1
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(ncols=2,nrows=2,figsize=(10,5))

# plot to each different axis
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10),np.random.random(10));
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
# subplot option 2
fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(10,5))

# Plot to each dufferent index
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10),np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# # lets plot through pandas df

# %%
import pandas as pd

# %%
# make a dataframe
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),index=pd.date_range("1/1/2020",periods=1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# converting price into numeric by removing other characters
car_sales["Price"] = car_sales["Price"].str.split(".").str[0].str.replace(r'[/$,]','',regex=True).astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sales Date"] = pd.date_range("1/1/2025",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date
# 0  Toyota  White         150043      4   4000 2025-01-01
# 1   Honda    Red          87899      4   5000 2025-01-02
# 2  Toyota   Blue          32549      3   7000 2025-01-03
# 3     BMW  Black          11179      5  22000 2025-01-04
# 4  Nissan  White         213095      4   3500 2025-01-05
# 5  Toyota  Green          99213      4   4500 2025-01-06
# 6   Honda   Blue          45698      4   7500 2025-01-07
# 7   Honda   Blue          54738      4   7000 2025-01-08
# 8  Toyota  White          60000      4   6250 2025-01-09
# 9  Nissan  White          31600      4   9700 2025-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2025-01-01         4000
# 1   Honda    Red          87899      4   5000 2025-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2025-01-03        16000
# 3     BMW  Black          11179      5  22000 2025-01-04        38000
# 4  Nissan  White         213095      4   3500 2025-01-05        41500
# 5  Toyota  Green          99213      4   4500 2025-01-06        46000
# 6   Honda   Blue          45698      4   7500 2025-01-07        53500
# 7   Honda   Blue          54738      4   7000 2025-01-08        60500
# 8  Toyota  White          60000      4   6250 2025-01-09        66750
# 9  Nissan  White          31600      4   9700 2025-01-10        76450

# %%
# lets plot the total sales
car_sales.plot(x="Sales Date",y="Total Sales");

# %%
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter");

# %%
car_sales.plot(x="Make",y="Doors",kind="bar");

# %%
# how about a bar
x = np.random.rand(10,4)

# Turn it into a df
df = pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.829464  0.530539  0.897857  0.610759
# 1  0.709368  0.113964  0.204084  0.014310
# 2  0.172982  0.406714  0.900785  0.546270
# 3  0.109242  0.820151  0.017219  0.890889
# 4  0.376261  0.909726  0.281736  0.385799
# 5  0.278537  0.150901  0.933922  0.947815
# 6  0.373586  0.285597  0.905084  0.581427
# 7  0.331595  0.260569  0.484779  0.762338
# 8  0.997726  0.411544  0.958463  0.915758
# 9  0.969055  0.580016  0.291161  0.767017

# %%
df.plot.bar();

# %%
df.plot(kind = "bar");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2025-01-01         4000
# 1   Honda    Red          87899      4   5000 2025-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2025-01-03        16000
# 3     BMW  Black          11179      5  22000 2025-01-04        38000
# 4  Nissan  White         213095      4   3500 2025-01-05        41500
# 5  Toyota  Green          99213      4   4500 2025-01-06        46000
# 6   Honda   Blue          45698      4   7500 2025-01-07        53500
# 7   Honda   Blue          54738      4   7000 2025-01-08        60500
# 8  Toyota  White          60000      4   6250 2025-01-09        66750
# 9  Nissan  White          31600      4   9700 2025-01-10        76450

# %%
car_sales.plot(x = "Make",y="Odometer (KM)",kind="bar");

# %%
(car_sales.groupby("Make")["Odometer (KM)"].sum()).plot(kind="bar");

# %%
# histogram
car_sales["Odometer (KM)"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Odometer (KM)"].plot(kind="hist",bins=10);

# %%
# lets try on another data
heart_disease = pd.read_csv("heart_disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# create a hist to see dist of age
heart_disease["age"].plot.hist(bins=50);

# %%
heart_disease.plot.hist(subplots=True,figsize=(10,30));

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
len(over_50)
# Out:
# 208

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# pyplot method
over_50.plot(kind="scatter",x="age",y="chol",c="target");

# %%
# 00 mixed with pyplot
fig,ax = plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",x="age",y="chol",c="target",ax=ax);
# ax.set_xlim([50,100]);

# %%
# object oriented method
fig,ax = plt.subplots(figsize=(10,6))

# plot the data
scatter = ax.scatter(x = over_50["age"],y=over_50["chol"],c=over_50["target"])

# customize the plot
ax.set(title="Heart Disease and Cholestrol Levels",xlabel="Age", ylabel="Cholestrol")

# add a legent
ax.legend(*scatter.legend_elements(),title="Target");

# add a horizantal line
ax.axhline(over_50["chol"].mean(),linestyle="dashed");

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# subplots of chol,age, thalach
fig,(ax0,ax1) = plt.subplots(figsize=(10,10),nrows=2,ncols=1,sharex=True)

# add data to ax0
scatter0 = ax0.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"]);

# customize ax0
ax0.set(title="Heart Disease and Cholestrol Levels", ylabel="Cholestrol")

# add a lefend to ax0
ax0.legend(*scatter0.legend_elements(),title="Target");

# add meanline
ax0.axhline(y = over_50["chol"].mean(),linestyle="dashed");


# now turn of second plot

# plot the data
scatter1 = ax1.scatter(x = over_50["age"], y=over_50["thalach"],c=over_50["target"])

# customize the plot ax1
ax1.set(title="Heart Disease and Max Heart Rate(thalach)",xlabel="Age",ylabel="Thalach")

# add a legend to the plot ax1
ax1.legend(*scatter1.legend_elements(),title = "Target");

# add a mean line
ax1.axhline(y = over_50["thalach"].mean(),linestyle="dashed");

# add a title to the figure
fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold");

# %% [markdown]
# # change the styles of plot(Customization)

# %%
# see the different styles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# subplots of chol,age, thalach
fig,(ax0,ax1) = plt.subplots(figsize=(10,10),nrows=2,ncols=1,sharex=True)

# add data to ax0
scatter0 = ax0.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"]);

# customize ax0
ax0.set(title="Heart Disease and Cholestrol Levels", ylabel="Cholestrol")

# add a lefend to ax0
ax0.legend(*scatter0.legend_elements(),title="Target");

# add meanline
ax0.axhline(y = over_50["chol"].mean(),linestyle="dashed");


# now turn of second plot

# plot the data
scatter1 = ax1.scatter(x = over_50["age"], y=over_50["thalach"],c=over_50["target"])

# customize the plot ax1
ax1.set(title="Heart Disease and Max Heart Rate(thalach)",xlabel="Age",ylabel="Thalach")

# add a legend to the plot ax1
ax1.legend(*scatter1.legend_elements(),title = "Target");

# add a mean line
ax1.axhline(y = over_50["thalach"].mean(),linestyle="dashed");

# add a title to the figure
fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold");

# %%
car_sales["Price"].plot();

# %%
plt.style.use("seaborn-v0_8-whitegrid")

# %%
car_sales["Price"].plot();

# %%
plt.style.use("seaborn-v0_8")

# %%
car_sales["Price"].plot();

# %%
car_sales.plot(x="Odometer (KM)", y ="Price", kind="scatter");

# %%
plt.style.use("ggplot")

# %%
car_sales["Price"].plot();

# %%
# create some data
x = np.random.randn(10,4)
x
# Out:
# array([[ 1.12334184,  0.53919141,  2.04683594, -1.21745789],
#        [ 0.51972678,  0.9849427 ,  1.31453657, -2.43914329],
#        [-0.59282284,  1.67623329, -1.72572368, -0.22848624],
#        [ 0.90213269,  0.77727412, -0.09707908, -1.18706682],
#        [-0.74114058, -0.17467094, -0.16896551, -0.953562  ],
#        [-0.28972009,  0.98370766,  1.19222545, -0.75459708],
#        [ 0.91933288,  0.59179902,  0.05146987,  0.1487059 ],
#        [-0.08842354,  2.1297039 ,  1.04346169,  0.58469583],
#        [-0.84724981,  2.16489198,  0.82656688, -1.00006807],
#        [-0.46791085, -0.34586663,  0.27812901,  1.03606483]])

# %%
df = pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  1.123342  0.539191  2.046836 -1.217458
# 1  0.519727  0.984943  1.314537 -2.439143
# 2 -0.592823  1.676233 -1.725724 -0.228486
# 3  0.902133  0.777274 -0.097079 -1.187067
# 4 -0.741141 -0.174671 -0.168966 -0.953562
# 5 -0.289720  0.983708  1.192225 -0.754597
# 6  0.919333  0.591799  0.051470  0.148706
# 7 -0.088424  2.129704  1.043462  0.584696
# 8 -0.847250  2.164892  0.826567 -1.000068
# 9 -0.467911 -0.345867  0.278129  1.036065

# %%
ax = df.plot(kind="bar")

# %%
# customize our plot
ax = df.plot(kind="bar")

# add some labels and title
ax.set(title="Random Number Bar Graph from Dataframe",xlabel="Row Number",ylabel="Random Number");

# make legend
ax.legend().set_visible(True);

# %%
# to change style
plt.style.use("seaborn-v0_8-whitegrid")

# subplots of chol,age, thalach
fig,(ax0,ax1) = plt.subplots(figsize=(10,10),nrows=2,ncols=1,sharex=True)

# add data to ax0
scatter0 = ax0.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"],cmap="winter");

# customize ax0
ax0.set(title="Heart Disease and Cholestrol Levels", ylabel="Cholestrol")

# add a lefend to ax0
ax0.legend(*scatter0.legend_elements(),title="Target");

# add meanline
ax0.axhline(y = over_50["chol"].mean(),linestyle="dashed");


# now turn of second plot

# plot the data
scatter1 = ax1.scatter(x = over_50["age"], y=over_50["thalach"],c=over_50["target"],cmap="winter")

# customize the plot ax1
ax1.set(title="Heart Disease and Max Heart Rate(thalach)",xlabel="Age",ylabel="Thalach")

# add a legend to the plot ax1
ax1.legend(*scatter1.legend_elements(),title = "Target");

# add a mean line
ax1.axhline(y = over_50["thalach"].mean(),linestyle="dashed");

# add a title to the figure
fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold");

# %%
# customizing xlim and ylim

# to change style
plt.style.use("seaborn-v0_8-whitegrid")

# subplots of chol,age, thalach
fig,(ax0,ax1) = plt.subplots(figsize=(10,10),nrows=2,ncols=1,sharex=True)

# add data to ax0
scatter0 = ax0.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"],cmap="winter");

# customize ax0
ax0.set(title="Heart Disease and Cholestrol Levels", ylabel="Cholestrol")
ax0.set_xlim([50,80])

# add a lefend to ax0
ax0.legend(*scatter0.legend_elements(),title="Target");

# add meanline
ax0.axhline(y = over_50["chol"].mean(),linestyle="dashed");


# now turn of second plot

# plot the data
scatter1 = ax1.scatter(x = over_50["age"], y=over_50["thalach"],c=over_50["target"],cmap="winter")

# customize the plot ax1
ax1.set(title="Heart Disease and Max Heart Rate(thalach)",xlabel="Age",ylabel="Thalach")
ax1.set_xlim([50,80])
ax1.set_ylim([60,200])

# add a legend to the plot ax1
ax1.legend(*scatter1.legend_elements(),title = "Target");

# add a mean line
ax1.axhline(y = over_50["thalach"].mean(),linestyle="dashed");

# add a title to the figure
fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold");

# %%
fig

# %%
fig.savefig("heart-disease-analysis-plot.png")
